# %% [markdown]
# # Project- Capstone: Deep Learning prediction of COVID-19 radiological imaging for improving the accuracy of diagnosis

# %% [markdown]
# ## Muhammad Tahir; Data Science Immersive @ General Assembly - April-2021

# %% [markdown]
# ## Part-1- Imports and Reading images

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

import tensorflow as tf
#tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.preprocessing.image import img_to_array, load_img

from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics

# For reproducibility
np.random.seed(42)

from glob import glob
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn.metrics import classification_report

bce = tf.keras.losses.BinaryCrossentropy()
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
test_image = load_img('../images/ARDSSevere.png', color_mode = 'grayscale')
test_image
# Out:
# <PIL.Image.Image image mode=L size=790x631 at 0x7FB69966F250>

# %%
image_array = img_to_array(test_image)

# %%
image_array
# Out:
# array([[[224.],
#         [224.],
#         [224.],
#         ...,
#         [224.],
#         [224.],
#         [224.]],
#
#        [[  0.],
#         [  0.],
#         [  0.],
#         ...,
#         [  0.],
#         [  0.],
#         [  0.]],
#
#        [[152.],
#         [147.],
#         [136.],
#         ...,
#         [  7.],
#         [  5.],
#         [  6.]],
#
#        ...,
#
#        [[ 20.],
#         [ 23.],
#         [ 23.],
#         ...,
#         [ 87.],
#         [ 85.],
#         [ 84.]],
#
#        [[ 21.],
#         [ 22.],
#         [ 26.],
#         ...,
#         [ 84.],
#         [ 86.],
#         [ 82.]],
#
#        [[ 22.],
#         [ 21.],
#         [ 23.],
#         ...,
#         [ 80.],
#         [ 81.],
#         [ 78.]]], dtype=float32)

# %%
image_array.squeeze().shape
# Out:
# (631, 790)

# %%
normalized_image = image_array / 255
plt.imshow(normalized_image)

# %%
# resize image
resize_image = load_img('../images/ARDSSevere.png', target_size=(64, 64))
resize_image
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB6785DE350>

# %%
res_image = img_to_array(resize_image)

# %%
res_image[:,:,2]
# Out:
# array([[123., 101.,  78., ...,  29.,  10.,  11.],
#        [141., 120., 117., ..., 101.,  95.,  91.],
#        [151., 142., 136., ...,  56.,  54.,  52.],
#        ...,
#        [128.,  82., 121., ..., 125., 118.,  91.],
#        [ 92.,  94.,  95., ..., 120., 118.,  95.],
#        [ 39.,  69.,  88., ..., 124., 105.,  93.]], dtype=float32)

# %%
# !ls -ll ../images | wc -l
# Out:
#      931

# %% [raw]
# # create list
# xray_arrays = []
# # define filepath for Dog class
# xray_path = '../images/'
#
# # convert each image to normalized array and store
# for file in os.listdir(xray_path):
#     try:
#         # target_size automatically resizes each img on import
#         xray = load_img(xray_path + file, target_size=(64, 64))
#         xray_arr = img_to_array(xray) / 255
#         xray_arrays.append(xray_arr)
#     except:
#         print(f'Error for file: {file}')
#
# print(f'{len(xray_arrays)} pictures converted.')

# %% [raw]
# xray_arrays[:1]

# %% [raw]
# type(xray_arrays)

# %% [markdown]
# ## Part-2: Exploratory Data Analysis

# %%
df = pd.read_csv('../metadata.csv')
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 29
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 2  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 3  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 4   diffuse infiltrates in the bilateral lower lungs         NaN         NaN
#
# [5 rows x 30 columns]

# %%
df = df[df['modality']=='X-ray']

# %%
df.shape
# Out:
# (866, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 866 entries, 0 to 949
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   patientid               866 non-null    object
#  1   offset                  660 non-null    float64
#  2   sex                     803 non-null    object
#  3   age                     636 non-null    float64
#  4   finding                 866 non-null    object
#  5   RT_PCR_positive         509 non-null    object
#  6   survival                341 non-null    object
#  7   intubated               225 non-null    object
#  8   intubation_present      227 non-null    object
#  9   went_icu                388 non-null    object
#  10  in_icu                  326 non-null    object
#  11  needed_supplemental_O2  86 non-null     object
#  12  extubated               37 non-null     object
#  13  temperature             74 non-null     float64
#  14  pO2_saturation          116 non-null    float64
#  15  leukocyte_count         15 non-null     float64
#  16  neutrophil_count        28 non-null     float64
#  17  lymphocyte_count        40 non-null     float64
#  18  view                    866 non-null    object
#  19  modality                866 non-null    object
#  20  date                    617 non-null    object
#  21  location                810 non-null    object
#  22  folder                  866 non-null    object
#  23  filename                866 non-null    object
#  24  doi                     369 non-null    object
#  25  url                     866 non-null    object
#  26  license                 631 non-null    object
#  27  clinical_notes          684 non-null    object
#  28  other_notes             405 non-null    object
#  29  Unnamed: 29             5 non-null      object
# dtypes: float64(7), object(23)
# memory usage: 209.7+ KB

# %%
df.columns
# Out:
# Index(['patientid', 'offset', 'sex', 'age', 'finding', 'RT_PCR_positive',
#        'survival', 'intubated', 'intubation_present', 'went_icu', 'in_icu',
#        'needed_supplemental_O2', 'extubated', 'temperature', 'pO2_saturation',
#        'leukocyte_count', 'neutrophil_count', 'lymphocyte_count', 'view',
#        'modality', 'date', 'location', 'folder', 'filename', 'doi', 'url',
#        'license', 'clinical_notes', 'other_notes', 'Unnamed: 29'],
#       dtype='object')

# %%
fnames = glob('../images/*')

# %%
fnames[:5]
# Out:
# ['../images/case_76_1-3.png',
#  '../images/54d57e77.jpg',
#  '../images/16745_2_2.PNG',
#  '../images/f6d980a0.jpg',
#  '../images/9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg']

# %%
fnames = [fname.split('/')[-1] for fname in fnames]

# %%
fnames[:5]
# Out:
# ['case_76_1-3.png',
#  '54d57e77.jpg',
#  '16745_2_2.PNG',
#  'f6d980a0.jpg',
#  '9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg']

# %%
df.shape
# Out:
# (866, 30)

# %%
df['label'] = df['finding'].apply(lambda x: 1 if x=='Pneumonia/Viral/COVID-19' else 0)
# Out:
# /Users/tahir/opt/anaconda3/envs/my-cool-project/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['label'].value_counts()
# Out:
# 1    504
# 0    362
# Name: label, dtype: int64

# %%
df_update = df[df['filename'].isin(fnames)]

# %%
df_update.shape
# Out:
# (866, 31)

# %%
# create list
xray_arrays = []
# define filepath for Dog class
xray_path = '../images/'

# convert each image to normalized array and store
for file in df_update.filename:
    try:
        # target_size automatically resizes each img on import
        xray = load_img(xray_path + file, target_size=(64, 64), color_mode = 'grayscale')
        xray_arr = img_to_array(xray) / 255
        xray_arrays.append(xray_arr)
    except:
        print(f'Error for file: {file}')

print(f'{len(xray_arrays)} pictures converted.')
# Out:
# 866 pictures converted.

# %%
xray_arrays[0].shape
# Out:
# (64, 64, 1)

# %%
df_update['label'].value_counts()
# Out:
# 1    504
# 0    362
# Name: label, dtype: int64

# %% [markdown]
# ## Train_test Split

# %%
# convert to array and check shape
X = np.array(xray_arrays)
print(f'X shape: {X.shape}')

# 1 for Pneumonia/Viral/COVID-19 and 0 for others
y = df_update['label']
# convert to array and check shape
y = np.array(y)
print(f'y shape: {y.shape}')
# Out:
# X shape: (866, 64, 64, 1)
# y shape: (866,)

# %%
X_train, X_heldout, y_train, y_heldout = train_test_split(X, y, test_size=0.12, random_state=42, stratify=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.14, random_state=42, stratify=y_train)

# %% [markdown]
# ## Model Training

# %%
model = Sequential()

# conv, pool
# 64 - n filters to use
# (3,3) - dimensions of each filter - pretty arbitrary here 
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(64,64,1)))
model.add(MaxPooling2D(pool_size=(2,2)))

# conv, pool
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# flatten
model.add(Flatten())
model.add(Dense(64, activation='relu'))

# output
model.add(Dense(1, activation='sigmoid'))

# compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.AUC()])
# Out:
# WARNING:tensorflow:From /Users/tahir/opt/anaconda3/envs/my-cool-project/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
#model = getModel()
#model.summary()
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2
batch_size = 64

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save = ModelCheckpoint('.mdl_wts_interpret.hdf5', save_best_only=True, monitor='val_loss', mode='min')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')

model_res = model.fit(X_train, y_train, batch_size=64, epochs=20, verbose=1, callbacks=[earlyStopping, mcp_save, reduce_lr_loss], validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 655 samples, validate on 107 samples
# Epoch 1/20
# 655/655 [==============================] - 7s 10ms/sample - loss: 0.7088 - acc: 0.5298 - auc: 0.4799 - val_loss: 0.6901 - val_acc: 0.5888 - val_auc: 0.6061
# Epoch 2/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.6808 - acc: 0.5847 - auc: 0.5312 - val_loss: 0.6725 - val_acc: 0.5794 - val_auc: 0.6260
# Epoch 3/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.6668 - acc: 0.5954 - auc: 0.6038 - val_loss: 0.6627 - val_acc: 0.5981 - val_auc: 0.6194
# Epoch 4/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.6521 - acc: 0.6305 - auc: 0.6530 - val_loss: 0.6447 - val_acc: 0.6262 - val_auc: 0.6570
# Epoch 5/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.6204 - acc: 0.6580 - auc: 0.7185 - val_loss: 0.6211 - val_acc: 0.6262 - val_auc: 0.6953
# Epoch 6/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.5960 - acc: 0.6901 - auc: 0.7454 - val_loss: 0.6054 - val_acc: 0.6449 - val_auc: 0.7220
# Epoch 7/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.5690 - acc: 0.7008 - auc: 0.7802 - val_loss: 0.5880 - val_acc: 0.6729 - val_auc: 0.7597
# Epoch 8/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.5376 - acc: 0.7344 - auc: 0.8047 - val_loss: 0.7726 - val_acc: 0.6168 - val_auc: 0.7968
# Epoch 9/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.5696 - acc: 0.7145 - auc: 0.7656 - val_loss: 0.5798 - val_acc: 0.6449 - val_auc: 0.7536
# Epoch 10/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.5180 - acc: 0.7389 - auc: 0.8295 - val_loss: 0.5288 - val_acc: 0.7196 - val_auc: 0.8088
# Epoch 11/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.4875 - acc: 0.7588 - auc: 0.8510 - val_loss: 0.5122 - val_acc: 0.7290 - val_auc: 0.8290
# Epoch 12/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.4703 - acc: 0.7740 - auc: 0.8610 - val_loss: 0.5333 - val_acc: 0.7570 - val_auc: 0.8185
# Epoch 13/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.4546 - acc: 0.7924 - auc: 0.8701 - val_loss: 0.4936 - val_acc: 0.7757 - val_auc: 0.8475
# Epoch 14/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.4140 - acc: 0.8244 - auc: 0.9062 - val_loss: 0.4923 - val_acc: 0.7664 - val_auc: 0.8543
# Epoch 15/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3956 - acc: 0.8290 - auc: 0.9111 - val_loss: 0.5017 - val_acc: 0.7757 - val_auc: 0.8475
# Epoch 16/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3918 - acc: 0.8275 - auc: 0.9045 - val_loss: 0.4941 - val_acc: 0.7570 - val_auc: 0.8561
# Epoch 17/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3655 - acc: 0.8443 - auc: 0.9245 - val_loss: 0.5031 - val_acc: 0.7757 - val_auc: 0.8652
# Epoch 18/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3667 - acc: 0.8412 - auc: 0.9188 - val_loss: 0.5681 - val_acc: 0.7477 - val_auc: 0.8335
# Epoch 19/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3585 - acc: 0.8443 - auc: 0.9274 - val_loss: 0.4843 - val_acc: 0.7850 - val_auc: 0.8557
# Epoch 20/20
# 655/655 [==============================] - 6s 9ms/sample - loss: 0.3330 - acc: 0.8626 - auc: 0.9380 - val_loss: 0.5171 - val_acc: 0.7944 - val_auc: 0.8376

# %%
preds = model.predict(X_test)

# %%
metrics.roc_auc_score(y_test, preds)
# Out:
# 0.8379928315412186

# %%
model = tf.keras.models.load_model('.mdl_wts_interpret.hdf5')
# Out:
# WARNING:tensorflow:From /Users/tahir/opt/anaconda3/envs/my-cool-project/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/tahir/opt/anaconda3/envs/my-cool-project/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
preds = model.predict(X_test)

# %%
metrics.roc_auc_score(y_test, preds)
# Out:
# 0.8559139784946236

# %%
confusion_matrix(y_test, preds.round())
# Out:
# array([[35, 10],
#        [13, 49]])

# %%
print(classification_report(y_test, preds.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75        45
#            1       0.83      0.79      0.81        62
#
#     accuracy                           0.79       107
#    macro avg       0.78      0.78      0.78       107
# weighted avg       0.79      0.79      0.79       107

# %% [markdown]
# ## Model Interpretability

# %%
import shap

# %%
background = X_train[np.random.choice(X_train.shape[0], 100, replace=False)]

# %%
e = shap.DeepExplainer(model, background)
# Out:
# WARNING:tensorflow:From /Users/tahir/opt/anaconda3/envs/my-cool-project/lib/python3.7/site-packages/shap/explainers/tf_utils.py:28: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.

# %% [markdown]
# #### Select pos examples based on a threshold

# %%
pos_indices = []
for i in range(0, preds.shape[0]):
    if preds[i] > 0.6 and y_test[i] == 1:
        pos_indices.append(i)

# %%
len(pos_indices)
# Out:
# 40

# %%
y_test[pos_indices[:5]], preds[pos_indices[:5]]
# Out:
# (array([1, 1, 1, 1, 1]),
#  array([[0.92559904],
#         [0.91414416],
#         [0.84584284],
#         [0.783322  ],
#         [0.7286112 ]], dtype=float32))

# %%
res = e.shap_values(X_test[pos_indices])

# %%
len(res)
# Out:
# 1

# %%
res[0][0].squeeze().shape
# Out:
# (64, 64)

# %%
plt.imshow(X_test[pos_indices[0]].squeeze(), cmap='gray')

# %%
index=0
plt.imshow(res[0][index].squeeze(), cmap='bwr', interpolation='gaussian')
plt.imshow(X_test[pos_indices[index]].squeeze(), cmap='gray', alpha=0.5)

# %%
shap.image_plot(res[:5], -X_test[pos_indices[:5]])

# %% [markdown]
# References:
#
#     1- https://stackoverflow.com/questions/48285129/saving-best-model-in-keras/48286003
