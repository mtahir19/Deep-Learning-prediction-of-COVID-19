# %%
import torchxrayvision as xrv
import matplotlib.pyplot as plt

# %%
dataset = xrv.datasets.COVID19_Dataset('../images/', '../metadata.csv')

# %%
plt.imshow(dataset[0]['img'].squeeze(), cmap='gray')
